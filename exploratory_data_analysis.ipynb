# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
df=pd.read_csv("cleaned_data.csv")

# %%
df.head(85)
# Out:
#         brand                 name  fuel_efficiency  cylinders  \
# 0   chevrolet      chevelle malibu             13.1          8
# 1       buick          skylark 320             15.7          8
# 2    plymouth            satellite             13.1          8
# 3         amc            rebel sst             14.7          8
# 4        ford               torino             13.8          8
# ..        ...                  ...              ...        ...
# 80     datsun             510 (sw)              8.4          4
# 81     toyota  corona mark ii (sw)             10.2          4
# 82      dodge            colt (sw)              8.4          4
# 83     toyota    corolla 1600 (sw)              8.7          4
# 84      buick          century 350             18.1          8
#
#     displacement(L)  horsepower  weight(kg)  acceleration  model_year origin
# 0               5.0       130.0        1589          12.0          70    usa
# ...

# %%
plt.figure(figsize=(17,3))
plt.xticks(rotation=60)
sns.barplot(x="brand",y="acceleration",data=df)
# Out:
# <Axes: xlabel='brand', ylabel='acceleration'>

# %%
plt.figure(figsize=(4,3))
plt.xticks(rotation=60)
plt.title("Menşeilere Yakıt Tüketim Ortalamaları")
sns.barplot(x="origin",y="fuel_efficiency",data=df)
# Out:
# <Axes: title={'center': 'Menşeilere Yakıt Tüketim Ortalamaları'}, xlabel='origin', ylabel='fuel_efficiency'>

# %%
df.plot(x="origin",y="acceleration",kind="line",figsize=(12,6))
plt.xticks(rotation=60)
plt.show()

# %%
df.loc[df["brand"]=="chevrolet","acceleration"].mean()
# Out:
# 15.397872340425533

# %%
df.loc[df["brand"]=="bmw","acceleration"].mean()
# Out:
# 12.65

# %%
df.loc[df["brand"]=="vw","acceleration"].mean()
# Out:
# nan

# %%
avg_by_name=df.groupby("name")["fuel_efficiency"].mean().sort_values(ascending=True)#Görüldüğü üzere ortalama olarak
avg_by_name.head(5)                                                                  #en az yakıt tüketen marka vw ve nissan
# Out:
# name
# glc                  5.0
# civic 1500 gl        5.3
# pickup               5.3
# rabbit c (diesel)    5.3
# dasher (diesel)      5.4
# Name: fuel_efficiency, dtype: float64

# %%
plt.figure(figsize=(10,3))##
plt.xticks(rotation=60,fontsize=8)
plt.title("Markalara Göre Yakıt Tüketimi")
plt.xlabel('Marka', fontsize=12)
plt.ylabel('Yakıt Tüketimi', fontsize=12)
sns.barplot(x="brand",y="fuel_efficiency",data=df)
# Out:
# <Axes: title={'center': 'Markalara Göre Yakıt Tüketimi'}, xlabel='Marka', ylabel='Yakıt Tüketimi'>

# %%
plt.figure(figsize=(15,3))##
plt.xticks(rotation=60,fontsize=8)
plt.xlabel("Marka",fontsize=12)
plt.ylabel("Beygir Gücü",fontsize=12)
plt.title("Markalara Göre Beygir Gücü")
sns.barplot(x="brand",y="horsepower",data=df)
# Out:
# <Axes: title={'center': 'Markalara Göre Beygir Gücü'}, xlabel='Marka', ylabel='Beygir Gücü'>

# %%
avg_by_name=df.groupby("brand")["horsepower"].mean().sort_values(ascending=False)#Görüldüğü üzere ortalama olarak
                                                    #beygir gücü en yüksek araç markaları sırasyıla chrysler cadillac pontiac


avg_by_name.head(5)
# Out:
# brand
# chrysler      153.666667
# cadillac      152.500000
# pontiac       136.937500
# buick         136.411765
# oldsmobile    122.000000
# Name: horsepower, dtype: float64

# %%
df.plot(x="weight(kg)",y="fuel_efficiency",kind="",marker="o")
# Out:
# <Axes: xlabel='weight(kg)', ylabel='fuel_efficiency'>

# %%
sns.regplot(x='weight(kg)', y='fuel_efficiency', data=df)
plt.title('Ağırlık ve Yakıt Tüketimi Üzerine Regresyon', fontsize=14)
plt.xlabel('Ağırlık (kg)', fontsize=12)
plt.ylabel('Yakıt Tüketimi (100km/l)', fontsize=12)
plt.grid(True)
plt.show()

# %%
sns.regplot(x='horsepower', y='fuel_efficiency', data=df)
plt.title('Beygir Gücü ve Yakıt Tüketimi Üzerine Regresyon', fontsize=14)
plt.xlabel('Beygir Gücü', fontsize=12)
plt.ylabel('Yakıt Tüketimi (100km/l)', fontsize=12)
plt.grid(True)
plt.show()

# %%
sns.regplot(x='displacement(L)', y='fuel_efficiency', data=df)
plt.title('Motor Hacmi ve Yakıt Tüketimi Üzerine Regresyon', fontsize=14)
plt.xlabel('Motor Hacmi(L)', fontsize=12)
plt.ylabel('Yakıt Tüketimi (100km/l)', fontsize=12)
plt.grid(True)
plt.show()

# %%
sns.regplot(x='displacement(L)', y='fuel_efficiency', data=df)
plt.title('Motor Hacmi ve Yakıt Verimliliği Üzerine Regresyon', fontsize=14)
plt.xlabel('Motor Hacmi(L)', fontsize=12)
plt.ylabel('Yakıt Verimliliği (100km/l)', fontsize=12)
plt.grid(True)
plt.show()

# %%
sns.regplot(x='model_year', y='horsepower', data=df)
plt.title('Beygir Gücünün Yıllara Göre Değişimi', fontsize=14)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Beygir Gücü', fontsize=12)
plt.grid(True)
plt.show()

# %%
sns.regplot(x='model_year', y='displacement(L)', data=df)
plt.title('Beygir Gücünün Yıllara Göre Değişimi', fontsize=14)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('hacim', fontsize=12)
plt.grid(True)
plt.show()

# %%
sns.regplot(x='model_year', y='fuel_efficiency', data=df)
plt.title('Beygir Gücünün Yıllara Göre Değişimi', fontsize=14)
plt.xlabel('Yıl', fontsize=12)
plt.ylabel('Yakıt Tüketimi (100km/l)', fontsize=12)
plt.grid(True)
plt.show()

# %%
# 'Content_Rating' kategorisine göre gruplama yapıp 'Installs' toplamını alıyoruz
install_by_rating = df.groupby('Content_Rating')['Installs'].sum()

# Pie chart çiziyoruz
plt.figure(figsize=(4, 4))
install_by_rating.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='Set3')

# Başlık ekliyoruz
plt.title('Total Installs by Content Rating')

# Grafiği göster
plt.ylabel('')  # Y eksenini gizliyoruz
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 2
#       1 # 'Content_Rating' kategorisine göre gruplama yapıp 'Installs' toplamını alıyoruz
# ----> 2 install_by_rating = df.groupby('Content_Rating')['Installs'].sum()
#       4 # Pie chart çiziyoruz
#       5 plt.figure(figsize=(4, 4))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
a=df['brand'].value_counts(normalize=True)*100



plt.figure(figsize=(10, 8))
brand_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='Set3')

# Grafiği başlıklandırma
plt.title('Araç Markalarına Göre Yüzde Dağılımı')

# Grafiği gösterme
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Örnek veri, burada df veri setinizi kullanmalısınız
# df = pd.read_csv('veri_seti.csv')  # Verinizi yüklemek için kullanabilirsiniz.

# Markaların yüzdelerini hesapla
brand_counts = df['brand'].value_counts(normalize=True) * 100

# %2'den küçük olanları "Diğer" olarak birleştir
threshold = 1.5
small_brands = brand_counts[brand_counts < threshold]  # %2'den küçük olanlar
brand_counts = brand_counts[brand_counts >= threshold]  # %2'den büyük olanlar

# Küçük markaların toplamını "Diğer" kategorisine ekle
brand_counts['Diğer'] = small_brands.sum()

# Pie grafiği oluşturma
plt.figure(figsize=(10, 8))
brand_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, 
                  pctdistance=0.85, labels=brand_counts.index, cmap='Set3')

# Çevresindeki iç içe çemberi ekleyerek görselliği iyileştirme
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Grafiği başlıklandırma
plt.title('Araç Markalarına Göre Yüzde Dağılımı (Diğer Kategorisi Dahil)')

# Grafiği gösterme
plt.show()

# %%
a=df["brand"].value_counts(normalize=True)*100
print(a)
# Out:
# brand
# ford             12.276215
# chevrolet        11.764706
# plymouth          7.928389
# dodge             7.161125
# amc               6.905371
# toyota            6.649616
# datsun            5.882353
# buick             4.347826
# pontiac           4.092072
# volkswagen        3.836317
# honda             3.324808
# mazda             3.069054
# mercury           2.813299
# oldsmobile        2.557545
# fiat              2.046036
# peugeot           2.046036
# audi              1.790281
# chrysler          1.534527
# volvo             1.534527
# vw                1.534527
# opel              1.023018
# saab              1.023018
# subaru            1.023018
# renault           0.767263
# bmw               0.511509
# mercedes-benz     0.511509
# cadillac          0.511509
# vokswagen         0.255754
# triumph           0.255754
# chevroelt         0.255754
# mercedes          0.255754
# capri             0.255754
# nissan            0.255754
# Name: proportion, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Örnek veri, burada df veri setinizi kullanmalısınız
# df = pd.read_csv('veri_seti.csv')  # Verinizi yüklemek için kullanabilirsiniz.

# Markaların yüzdelerini hesapla
brand_counts = df['brand'].value_counts(normalize=True) * 100

# %1.5'ten küçük olanları "Diğer" olarak birleştir
threshold = 1.5
small_brands = brand_counts[brand_counts < threshold]  # %1.5'ten küçük olanlar
brand_counts = brand_counts[brand_counts >= threshold]  # %1.5'ten büyük olanlar

# Küçük markaların toplamını "Diğer" kategorisine ekle
brand_counts['Diğer'] = small_brands.sum()

# Pie grafiği oluşturma
plt.figure(figsize=(10, 8))

# Farklı renkler atama (her markaya bir renk)
colors = plt.cm.tab20c(range(len(brand_counts)))

# Pie grafiği
plt.pie(brand_counts, labels=brand_counts.index, autopct='%1.1f%%', startangle=90, 
        pctdistance=0.85, colors=colors, wedgeprops={'edgecolor': 'black'})

# Ortadaki boşluğu kaldırma (inner circle'ı kaldırıyoruz)


# Grafiği başlıklandırma
plt.title('Araç Markalarına Göre Yüzde Dağılımı')

# Grafiği gösterme
plt.show()

# %%
df.describe().T
# Out:
#                  count         mean         std    min      25%     50%  \
# fuel_efficiency  391.0    11.210230    3.849282    5.0     8.10    10.2
# cylinders        391.0     5.465473    1.703152    3.0     4.00     4.0
# displacement(L)  391.0     3.187468    1.711461    1.1     1.70     2.5
# horsepower       391.0   104.242967   38.278196   46.0    75.00    93.0
# weight(kg)       391.0  1348.580563  383.663331  732.0  1009.00  1270.0
# acceleration     391.0    15.533760    2.758323    8.0    13.75    15.5
# model_year       391.0    75.994885    3.675975   70.0    73.00    76.0
#
#                      75%     max
# fuel_efficiency    13.60    23.5
# cylinders           8.00     8.0
# displacement(L)     4.35     7.5
# horsepower        125.00   230.0
# weight(kg)       1638.00  2331.0
# acceleration       17.00    24.8
# model_year         79.00    82.0

# %%
sorted(df["brand"].unique())
# Out:
# ['amc',
#  'audi',
#  'bmw',
#  'buick',
#  'cadillac',
#  'capri',
#  'chevroelt',
#  'chevrolet',
#  'chrysler',
#  'datsun',
#  'dodge',
#  'fiat',
#  'ford',
#  'honda',
#  'mazda',
#  'mercedes',
#  'mercedes-benz',
#  'mercury',
#  'nissan',
#  'oldsmobile',
#  'opel',
#  'peugeot',
#  'plymouth',
#  'pontiac',
#  'renault',
#  'saab',
#  'subaru',
#  'toyota',
#  'triumph',
#  'vokswagen',
#  'volkswagen',
#  'volvo',
#  'vw']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 a=a.sort()
#       2 print(a)
#
# AttributeError: 'NoneType' object has no attribute 'sort'
